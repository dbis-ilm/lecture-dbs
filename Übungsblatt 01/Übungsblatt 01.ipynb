-- %% [markdown]
-- # SQL Grundlagen und Relationale Algebra

-- %% [markdown]
-- Laden Sie die Daten, bevor Sie mit der Arbeit beginnen.

-- %%
%CREATE :memory: OF universitaet.sql
%LOAD_TESTS tests.json
%GUESS_PARSER

-- %% [markdown]
-- Das folgende Diagramm zeigt die Struktur der Tabellen.
-- ```mermaid
-- %%{init: {
--   'flowchart': {
--     'nodeSpacing': 0,
--     'rankSpacing': 24,
--     'padding': 10
--   }
-- }}%%
-- flowchart TD
--     classDef table fill:none,stroke:#888,stroke-width:1px;
--
--     subgraph E1 [ ]
--         direction TB
--         Fakultaet["
--             <table>
--                 <tr>
--                     <th colspan=3 style='border-bottom: 2px solid'>▦ Fakultaet</th>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right'>🔑</td>
--                     <td style='padding: 0 8px 0 0; text-align:left'><b>ID</b></td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>Name</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>varchar(255)</td>
--                 </tr>
--             </table>
--         "]
--     end
--
--     subgraph E2 [ ]
--         direction LR
--         Studiengang["
--             <table>
--                 <tr>
--                     <th colspan='3' style='border-bottom: 2px solid'>▦ Studiengang</th>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'>🔑</td>
--                     <td style='padding: 0 8px 0 0; text-align:left'><b>ID</b></td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>Name</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>varchar(255)</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>BachelorMaster</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>varchar(1)</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'>🔗</td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>FakultaetID</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>GesamtLP</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--             </table>
--         "]
--         Student["
--             <table>
--                 <tr>
--                     <th colspan='3' style='border-bottom: 2px solid'>▦ Student</th>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'>🔑</td>
--                     <td style='padding: 0 8px 0 0; text-align:left'><b>Matrikelnummer</b></td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>Vorname</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>varchar(255)</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>Nachname</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>varchar(255)</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>Semester</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--             </table>
--         "]
--     end
--
--     subgraph E3 [ ]
--         direction LR
--         Fach["
--             <table>
--                 <tr>
--                     <th colspan='3' style='border-bottom: 2px solid'>▦ Fach</th>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'>🔑</td>
--                     <td style='padding: 0 8px 0 0; text-align:left'><b>ID</b></td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>Name</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>varchar(255)</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>Leistungspunkte</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'>🔗</td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>StudiengangID</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--             </table>
--         "]
--         Anmeldung["
--             <table>
--                 <tr>
--                     <th colspan='3' style='border-bottom: 2px solid'>▦ Anmeldung</th>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'>🔑🔗</td>
--                     <td style='padding: 0 8px 0 0; text-align:left'><b>Matrikelnummer</b></td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'>🔑🔗</td>
--                     <td style='padding: 0 8px 0 0; text-align:left'><b>StudiengangID</b></td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>ImmaDatum</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>date</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>ExmaDatum</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>date</td>
--                 </tr>
--             </table>
--         "]
--         Pruefung["
--             <table>
--                 <tr>
--                     <th colspan='3' style='border-bottom: 2px solid'>▦ Pruefung</th>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'>🔑🔗</td>
--                     <td style='padding: 0 8px 0 0; text-align:left'><b>Matrikelnummer</b></td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>int</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'>🔑🔗</td>
--                     <td style='padding: 0 8px 0 0; text-align:left'><b>FachID</b></td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>varchar(255)</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>Datum</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>date</td>
--                 </tr>
--                 <tr>
--                     <td style='text-align:right; white-space: nowrap'></td>
--                     <td style='padding: 0 8px 0 0; text-align:left'>Note</td>
--                     <td style='padding: 0 0 0 8px; text-align:right'>float</td>
--                 </tr>
--             </table>
--         "]
--     end
--
--     style E1 fill:none,stroke:none
--     style E2 fill:none,stroke:none
--     style E3 fill:none,stroke:none
--
--     Studiengang -- "FakultaetID:ID" --> Fakultaet
--     Fach -- "StudiengangID:ID" --> Studiengang
--     Anmeldung -- "StudiengangID:ID" --> Studiengang
--     Anmeldung -- "Matrikelnummer" --> Student
--     Pruefung -- "Matrikelnummer" --> Student
-- ```

-- %% [markdown]
-- ## Teil 1: SQL und RA
-- **Hinweis:** Alle Anfragen sind mit den SQL-Konstrukten aus den Handouts lösbar (*Grundlagen relationaler Datenbanken*). Außerdem: Wenn nach "Wie viele" (bzw. einer Anzahl) gefragt ist, genügt es diese abzulesen, es wird kein `COUNT` o.ä. benötigt.

-- %% [markdown]
-- ### Aufgabe 1
-- Geben Sie alle Studiengänge der Studiengang-Relation aus. Wie viele sind es?

-- %%
%TEST aufgabe1
SELECT 1

-- %% [markdown]
-- ### Aufgabe 2
-- Geben Sie aus der Studiengang-Relation für jeden Studiengang nur den Namen aus.

-- %%
%TEST aufgabe2-1
SELECT 1

-- %% [markdown]
-- Was muss an der Anfrage geändert werden, so dass keine Duplikate (hier: Informatik) entstehen? (SQL+RA)

-- %%
%TEST aufgabe2-2
SELECT 1

-- %%
%TEST aufgabe2-2
Studiengang

-- %% [markdown]
-- ### Aufgabe 3
-- Berechnen Sie das Kreuzprodukt zwischen den Relationen Student und Pruefung. (SQL+RA)

-- %%
%TEST aufgabe3-1
SELECT 1

-- %%
%TEST aufgabe3-1
Student

-- %% [markdown]
-- Berechnen Sie den natürlichen Verbund zwischen den Relationen Student und Pruefung. (SQL+RA)

-- %%
%TEST aufgabe3-2
SELECT 1

-- %%
%TEST aufgabe3-2
Student

-- %% [markdown]
-- Wie viele Tupel entstehen jeweils im Ergebnis?

-- %% [markdown]
-- ### Aufgabe 4
-- Geben Sie alle Bachelor-Studiengänge der Studiengang-Relation aus.

-- %%
%TEST aufgabe4-1
SELECT 1

-- %%
%TEST aufgabe4-1
Studiengang

-- %% [markdown]
-- Reduzieren Sie das Ergebnis anschließend zusätzlich auf alle Bachelor-Studiengänge der Fakultät "Informatik und
-- Automatisierung" (`FakultaetID` ist 1). Welche sind das?

-- %%
%TEST aufgabe4-2
SELECT 1

-- %%
%TEST aufgabe4-2
Studiengang

-- %% [markdown]
-- ### Aufgabe 5
-- Finden Sie die Studenten, die noch keine Prüfung abgelegt haben. Wie viele sind es?

-- %%
%TEST aufgabe5
SELECT 1

-- %%
%TEST aufgabe5
Student

-- %% [markdown]
-- ## Teil 2: Änderungen
-- Bei diesen Aufgaben wird die Datenbank verändert. Sie können jederzeit die Daten zurücksetzen, indem Sie die nachfolgende Zelle ausführen.

-- %%
%CREATE :memory: OF universitaet.sql

-- %% [markdown]
-- ### Aufgabe 6
-- Fügen Sie den neuen Studierenden Hans Kauzig der Tabelle Student hinzu. Seine Matrikelnummer soll $40017$ lauten und er beginnt im Semester $1$.

-- %%
-- INSERT ...

-- %%
%TEST aufgabe6
SELECT * FROM Student WHERE Matrikelnummer = 40017

-- %% [markdown]
-- Was passiert, wenn Sie den Studierenden ein zweites Mal identisch anlegen wollen?

-- %%
-- INSERT ...

-- %% [markdown]
-- - Warum können Sie den Studenten kein zweites Mal anlegen?
-- - Können Sie Attribute leer lassen (=`NULL`)? Falls ja, welche?

-- %% [markdown]
-- ### Aufgabe 7
-- Der neue Studierende Hans Kauzig hat geheiratet. Sein neuer Nachname ist nun Zander. Bringen Sie diese Änderung in die Datenbank ein.

-- %%
-- UPDATE ...

-- %%
%TEST aufgabe7
SELECT * FROM Student WHERE Matrikelnummer = 40017

-- %% [markdown]
-- ### Aufgabe 8
-- Hans Zander ist nun ohne Angabe von Gründen von seinem Studium zurückgetreten. Löschen Sie ihn aus der Datenbank.

-- %%
-- DELETE ...

-- %%
%TEST aufgabe8
SELECT * FROM Student WHERE Matrikelnummer = 40017

-- %% [markdown]
-- ### Aufgabe 9
-- Die Universität hat beschlossen, zusätzlich ihre Mitarbeiter in der Datenbank zu speichern. Hierzu ist eine neue Tabelle mit dem folgenden Relationenschema anzulegen:
--
-- **Mitarbeiter** ( <u>PersID</u> , Vorname , Nachname , Gehalt , FakultaetID $\rightarrow$ Fakultaet(ID) )
--
-- Erstellen Sie diese. Berücksichtigen Sie Primär- und Fremdschlüssel. Das Gehalt ist als optional anzugeben, alle anderen Attribute müssen Werte enthalten.

-- %%
-- CREATE TABLE

-- %% [markdown]
-- Testen Sie ihre Tabelle anschließend, indem Sie selbst gewählte Tupel einfügen. Versuchen Sie ebenfalls, Tupel einzufügen, welche die Integritätsbedingungen verletzen.

-- %%
-- INSERT ...

-- %%
SELECT * FROM Mitarbeiter

-- %% [markdown]
-- ## Teil 3: Erweitertes SQL

-- %% [markdown]
-- ### Aufgabe 10
-- Welche Studierenden haben bereits eine $1.0$ oder $1.3$ in mindestens einer ihrer abgelegten Prüfungen erreicht? Gesucht sind Vor- und Nachname der Studierenden.

-- %%
%TEST aufgabe10
SELECT 1

-- %% [markdown]
-- ### Aufgabe 11
-- Welche Fächer (*Name*) haben Studierende des Studiengangs Informatik besucht, die bereits mindestens im sechsten Semester sind? Gesucht ist der Name der Fächer.

-- %%
%TEST aufgabe11
SELECT 1

-- %% [markdown]
-- ### Aufgabe 12
-- Welche Fakultäten (*Name*) bieten keine Masterstudiengänge an?

-- %%
%TEST aufgabe12
SELECT 1
